# %%
import requests
import json
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np
import config

# %%
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
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 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
#
# NameError: name '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' is not defined

# %%
# Set up authentication
headers = {'Authorization': 'Bearer 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'}

# Make request to API
response = requests.get('https://api.github.com/hashicorp/psf/requests', headers=headers)

# Parse response
data = json.loads(response.content)
#print('Repository name:', data['name'])
#print('Number of stars:', data['stargazers_count'])
#print('Number of forks:', data['forks_count'])

# %%
# Set up authentication (if required)
headers = {'Authorization': 'Bearer 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'}

# Define the API endpoint URL
url = 'https://api.github.com/repos/sqali/Github-Aggregator'

# Make a GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = json.loads(response.content)
    # Extract the repository data
    name = data['name']
    stargazers = data['stargazers_count']
    forks = data['forks_count']
    print(f"Repository name: {name}")
    print(f"Number of stargazers: {stargazers}")
    print(f"Number of forks: {forks}")
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# Repository name: Github-Aggregator
# Number of stargazers: 0
# Number of forks: 0

# %%
# Set up authentication (if required)
headers = {'Authorization': 'Bearer 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'}

# Define the API endpoint URL
url = 'https://api.github.com/orgs/hashicorp/repos'

# Make a GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = json.loads(response.content)
    print(data)
    # Extract the repository data
    #name = data['name']
    #stargazers = data['stargazers_count']
    #forks = data['forks_count']
    #print(f"Repository name: {name}")
    #print(f"Number of stargazers: {stargazers}")
    #print(f"Number of forks: {forks}")
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# [{'id': 481872, 'node_id': 'MDEwOlJlcG9zaXRvcnk0ODE4NzI=', 'name': 'vagrant', 'full_name': 'hashicorp/vagrant', 'private': False, 'owner': {'login': 'hashicorp', 'id': 761456, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc2MTQ1Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/761456?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/hashicorp', 'html_url': 'https://github.com/hashicorp', 'followers_url': 'https://api.github.com/users/hashicorp/followers', 'following_url': 'https://api.github.com/users/hashicorp/following{/other_user}', 'gists_url': 'https://api.github.com/users/hashicorp/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/hashicorp/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/hashicorp/subscriptions', 'organizations_url': 'https://api.github.com/users/hashicorp/orgs', 'repos_url': 'https://api.github.com/users/hashicorp/repos', 'events_url': 'https://api.github.com/users/hashicorp/events{/privacy}', 'received_even
# ...

# %%
headers = {'Authorization': 'Bearer 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'}

# Define the API endpoint URL for the HashiCorp organization repositories
url = 'https://api.github.com/orgs/hashicorp/repos'

# Make a GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = json.loads(response.content)
    
    # Loop through each repository in the response data
    for repo in data:
        repo_name = repo['name']
        repo_url = repo['url']
        
        # Make a GET request to the repository endpoint to retrieve contributors
        response = requests.get(f"{repo_url}/contributors", headers=headers)
        
        # Check the response status code
        if response.status_code == 200:
            # Parse the JSON response
            contributors = json.loads(response.content)
            
            # Extract the names of the contributors and print them to the console
            contributor_names = [contributor['login'] for contributor in contributors]
            print(f"Contributors for repository {repo_name}: {', '.join(contributor_names)}")
        else:
            print(f"Request failed with status code {response.status_code}")
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# Contributors for repository vagrant: mitchellh, chrisroberts, briancain, soapy1, sethvargo, gildegoma, phinze, jbonhag, fgrehm, johnbender, sneal, tmatilai, justincampbell, jescalan, vagrant-bot, kaitlincart, bbrala, maxlinc, dcermak, benh57, pearkes, mwrock, kikitux, jasoncostello, captainill, legal90, berendt, jtopper, zachflower, ashleemboyer
# Contributors for repository vagrant-installers: chrisroberts, mitchellh, soapy1, vagrant-bot, sethvargo, briancain, StefanScherer, ogarcia, benesch, CalebAlbers, nacht, vancluever, danp, dbishop, drnic, glensc, emyl, fnichol, hjr3, trinitronx, kimhmadsen, Hades32, sschuberth, g0t4, hashicorp-copywrite[bot]
# Contributors for repository puppet-bootstrap: mitchellh, grubernaut, mattr-, stagrlee, ptomulik, ferventcoder, schrepfler, michaelkrieg, Filirom1, Aethylred, antonlindstrom, CalebAlbers, danieldreier, ddrager, emyl, finn, grahamgilbert, jmaslibre, kian, mariusvw, wickedshimmy, braf, cappetta, zakdoek
# ...

# %%
headers = {'Authorization': 'Bearer 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'}

# Define the API endpoint URL for the HashiCorp organization repositories
url = 'https://api.github.com/orgs/hashicorp/repos'

# Make a GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = json.loads(response.content)
    
    # Loop through each repository in the response data
    for repo in data:
        repo_name = repo['name']
        repo_url = repo['url']
        
        # Make a GET request to the repository endpoint to retrieve contributors
        response = requests.get(f"{repo_url}/contributors", headers=headers)
        
        # Check the response status code
        if response.status_code == 200:
            # Parse the JSON response
            contributors = json.loads(response.content)
            
            # Loop through each contributor and make a request to their profile endpoint to get their organization
            for contributor in contributors:
                contributor_name = contributor['login']
                contributor_url = contributor['url']
                
                # Make a GET request to the contributor's profile endpoint to get their organization
                response = requests.get(contributor_url, headers=headers)
                
                # Check the response status code
                if response.status_code == 200:
                    # Parse the JSON response and extract the organization
                    profile_data = json.loads(response.content)
                    organization = profile_data['company']
                    
                    # Print the contributor name and organization to the console
                    print(f"{contributor_name} ({organization}) contributed to repository {repo_name}")
                else:
                    print(f"Request failed with status code {response.status_code}")
        else:
            print(f"Request failed with status code {response.status_code}")
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# mitchellh (HashiCorp) contributed to repository vagrant
# chrisroberts (None) contributed to repository vagrant
# briancain (@hashicorp) contributed to repository vagrant
# soapy1 (@nytimes) contributed to repository vagrant
# sethvargo (@Google) contributed to repository vagrant
# gildegoma (@swisstxt) contributed to repository vagrant
# phinze (@hashicorp ) contributed to repository vagrant
# jbonhag (None) contributed to repository vagrant
# fgrehm (None) contributed to repository vagrant
# johnbender (UCLA Computer Science Dept.) contributed to repository vagrant
# sneal (VMware) contributed to repository vagrant
# tmatilai (@iceye-ltd) contributed to repository vagrant
# justincampbell (None) contributed to repository vagrant
# jescalan (None) contributed to repository vagrant
# vagrant-bot (HashiCorp) contributed to repository vagrant
# kaitlincart (None) contributed to repository vagrant
# bbrala (@swisnl ) contributed to repository vagrant
# ...

# %%
import requests
import json

# Define the authorization token
headers = {'Authorization': 'Bearer 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'}

# Define the API endpoint URL for the HashiCorp organization repositories
url = 'https://api.github.com/orgs/hashicorp/repos'

# Make a GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = json.loads(response.content)
    
    # Loop through each repository in the response data
    for repo in data:
        repo_name = repo['name']
        repo_url = repo['url']
        
        # Make a GET request to the repository endpoint to retrieve contributors
        response = requests.get(f"{repo_url}/contributors", headers=headers)
        
        # Check the response status code
        if response.status_code == 200:
            # Parse the JSON response
            contributors = json.loads(response.content)
            
            # Loop through each contributor and make a request to their profile endpoint to get their organization
            for contributor in contributors:
                contributor_name = contributor['login']
                contributor_url = contributor['url']
                
                # Make a GET request to the contributor's profile endpoint to get their organization
                response = requests.get(contributor_url, headers=headers)
                
                # Check the response status code
                if response.status_code == 200:
                    # Parse the JSON response and extract the organization
                    profile_data = json.loads(response.content)
                    organization = profile_data['company']
                    
                    # Print the contributor name, organization, and repository name to the console
                    print(f"{contributor_name} ({organization}) contributed to branch {repo_name}/{contributor['login']} in repository {repo_name}")
                else:
                    print(f"Request failed with status code {response.status_code}")
        else:
            print(f"Request failed with status code {response.status_code}")
else:
    print(f"Request failed with status code {response.status_code}")

# %%
# Set up authentication (if required)
headers = {'Authorization': 'Bearer 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'}

# Define the API endpoint URL for the hashicorp/consul repository
url = 'https://api.github.com/repos/hashicorp/consul'

# Make a GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = json.loads(response.content)
    print(data)
    # Extract the repository data
    name = data['name']
    stargazers = data['stargazers_count']
    forks = data['forks_count']
    description = data['description']
    default_branch = data['default_branch']
    language = data['language']
    html_url = data['html_url']
    print(f"Repository name: {name}")
    print(f"Number of stargazers: {stargazers}")
    print(f"Number of forks: {forks}")
    print(f"Description: {description}")
    print(f"Default branch: {default_branch}")
    print(f"Language: {language}")
    print(f"HTML URL: {html_url}")
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 url = 'https://api.github.com/repos/hashicorp/consul'
#       7 # Make a GET request to the API endpoint
# ----> 8 response = requests.get(url, headers=headers)
#      10 # Check the response status code
#      11 if response.status_code == 200:
#      12     # Parse the JSON response
#
# NameError: name 'requests' is not defined
